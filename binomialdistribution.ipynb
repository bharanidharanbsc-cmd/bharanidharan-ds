# %%
import matplotlib.pyplot as plt
from scipy.stats import binom
import numpy as np
n=15
p=0.6
k=10
probability=binom.pmf(k,n,p)
print(probability)
# Out:
# 0.1859378447646719

# %%
x=np.arange(0,n+1)
pmf_values=binom.pmf(x,n,p)
plt.bar(x,pmf_values,color="violet",edgecolor="black",label="Binomial PMF")
plt.bar(k,probability,color="green",edgecolor="black",label=f"k={k}")
plt.xlabel("number of success")
plt.ylabel("probability")
plt.title("Binomail Distribution")
plt.legend()
plt.grid(axis="y",alpha=.5)
plt.show()

# %%
from scipy.stats import binom
n=12
p=0.7
k=10
prob=binom.cdf(k,n,p)
print(prob)
# Out:
# 0.914974950051

# %%
s=np.arange(0,n+2)
cdf_values=binom.cdf(s,n,p)
plt.bar(s,cdf_values,color="blue",edgecolor="black",label="Binomail CDF")
plt.bar(k,prob,color="white",edgecolor="black",label=f"k={k}")
plt.title("binomail Distribution")
plt.xlabel("success")
plt.ylabel("porbability")
plt.legend()
plt.show()

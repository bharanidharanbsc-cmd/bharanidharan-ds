# %%
import regex as re
text="the mail id is abc123@gmail.com and efg456@gmail.com"
a=re.findall(r'\w{2,}@\w{2,}.\w{2,}',text)
a
# Out:
# ['abc123@gmail.com', 'efg456@gmail.com']

# %%
text=input("enter your text:")
a=re.findall(r'123@',text)
if a:
    print("yes available")
else:
    print("not available")
# Out:
# enter your text: 123
# not available

# %%
set="i am a little boy and i have five friends"
search=re.search(r'boy',set)
search
# Out:
# <regex.Match object; span=(14, 17), match='boy'>

# %%
txt="i am a little boy and i have five friends"
search=re.search(r'boy',txt)
search
# Out:
# <regex.Match object; span=(14, 17), match='boy'>

# %%
phone="my password is 12345"
b=re.search(r'\d',phone)
b
# Out:
# <regex.Match object; span=(15, 16), match='1'>

# %%
text="roman123 is my passcode"
extract=re.search(r'\d',text)
extract
# Out:
# <regex.Match object; span=(5, 6), match='1'>

# %%
text="roman123 is my passcode"
extract=re.search(r'\D',text)
extract
# Out:
# <regex.Match object; span=(0, 1), match='r'>

# %%
text="roman123 is my passcode"
extract=re.search(r'\s',text)
extract
# Out:
# <regex.Match object; span=(8, 9), match=' '>

# %%
news="today is rainy"
s=re.sub(r'toay',"",mail)
s
